# %% [markdown]
# # Who votes with the United States in the United Nations?
# Every year the U.S. State Department reports to Congress on how often other countries vote with the U.S. in the UN.

# %%
import pandas as pd
un = pd.read_csv("https://raw.githubusercontent.com/markschaver/UN/master/un-coincidence-2020.csv", sep=",")
# %matplotlib inline

# %% [markdown]
# # Voting coincidence
# ## Which country voted most often with the U.S. in 2020?

# %%
un[un['COINCIDENCE'] == un['COINCIDENCE'].max()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/schav/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///c%3A/Users/schav/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/schav/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'COINCEDENCE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\schav\OneDrive\Data\UN\UN.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/schav/OneDrive/Data/UN/UN.ipynb#ch0000003?line=0'>1</a> un[un['COINCEDENCE'] == un['COINCEDENCE'].max()]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/schav/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///c%3A/Users/schav/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/schav/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/schav/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///c%3A/Users/schav/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/schav/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/schav/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/schav/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/schav/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///c%3A/Users/schav/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/schav/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/schav/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/schav/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'COINCEDENCE'

# %% [markdown]
# ## Which countries voted least often with the U.S. in 2020?

# %%
un[un['Voting Coincidence'] == un['Voting Coincidence'].min()]
# Out:
#                    Country   ISO  Same  Opposite  Partial  Absent  \
# 27                Burundi   BDI      6        72       14      18
# 168  Syrian Arab Republic   SYR      8        83       14       5
#
#      Voting Coincidence
# 27                 0.14
# 168                0.14

# %%
un['Voting Coincidence'].hist()

# %% [markdown]
# # Absenteeism

# %%
un['Absent'].hist()

# %% [markdown]
# ## Which country was absent most often?

# %%
un[un['Absent'] == un['Absent'].max()]
# Out:
#       Country   ISO  Same  Opposite  Partial  Absent  Voting Coincidence
# 159  Somalia   SOM      6        25        1      78                 0.2

# %% [markdown]
# ## Which countries were absent least often?

# %%
un[un['Absent'] == un['Absent'].min()]
# Out:
#                                                Country   ISO  Same  Opposite  \
# 2                                             Algeria   DZA     10        78
# 6                                           Argentina   ARG     21        69
# 9                                             Austria   AUT     36        48
# 12                                            Bahrain   BHR     18        76
# 13                                         Bangladesh   BGD     15        76
# 16                                            Belgium   BEL     42        43
# 23                                             Brazil   BRA     20        70
# 25                                           Bulgaria   BGR     40        41
# 31                                             Canada   CAN     57        24
# 39                                         Costa Rica   CRI     24        73
# 41                                            Croatia   HRV     41        40
# 43                                             Cyprus   CYP     35        53
# 44                                            Czechia   CZE     46        38
# 47                                            Denmark   DNK     43        41
# 51                                            Ecuador   ECU     18        77
# 56                                            Estonia   EST     45        43
# 60                                            Finland   FIN     39        45
# 61                                             France   FRA     51        37
# 65                                            Germany   DEU     44        41
# 67                                             Greece   GRO     41        46
# 75                                            Hungary   HUN     50        35
# 77                                              India   IND     20        74
# 78                                          Indonesia   IDN     13        79
# 81                                            Ireland   IRL     36        52
# 83                                              Italy   ITA     42        39
# 85                                              Japan   JPN     34        43
# 93                                             Latvia   LVA     45        39
# 99                                          Lithuania   LTU     44        38
# 100                                        Luxembourg   LUX     42        45
# 106                                             Malta   MLT     35        53
# 110                                            Mexico   MEX     20        64
# 122                                       New Zealand   NZL     36        51
# 127                                            Norway   NOR     39        44
# 135                                       Philippines   PHL     15        73
# 137                                          Portugal   PRT     40        45
# 138                                             Qatar   QAT     18        77
# 141                                           Romania   ROU     43        39
# 142                                Russian Federation   RUS     21        70
# 148                                        San Marino   SMR     35        50
# 150                                      Saudi Arabia   SAU     21        76
# 155                                         Singapore   SGP     17        71
# 162                                             Spain   ESP     40        43
# 166                                            Sweden   SWE     37        48
# 170                                          Thailand   THA     15        73
# 181                              United Arab Emirates   ARE     16        77
# 182  United Kingdom of Great Britain and Northern I...  GBR     54        35
#
#      Partial  Absent  Voting Coincidence
# 2         22       0                0.19
# 6         20       0                0.28
# 9         26       0                0.45
# 12        16       0                0.24
# 13        19       0                0.22
# 16        25       0                0.50
# 23        20       0                0.27
# 25        29       0                0.50
# 31        29       0                0.65
# 39        13       0                0.28
# 41        29       0                0.50
# 43        22       0                0.42
# 44        26       0                0.54
# 47        26       0                0.51
# 51        15       0                0.23
# 56        22       0                0.51
# 60        26       0                0.47
# 61        22       0                0.56
# 65        25       0                0.51
# 67        23       0                0.48
# 75        25       0                0.57
# 77        16       0                0.25
# 78        18       0                0.20
# 81        22       0                0.43
# 83        29       0                0.51
# 85        33       0                0.46
# 93        26       0                0.53
# 99        28       0                0.53
# 100       23       0                0.49
# 106       22       0                0.42
# 110       26       0                0.30
# 122       23       0                0.43
# 127       27       0                0.48
# 135       22       0                0.24
# 137       25       0                0.48
# 138       15       0                0.23
# 141       28       0                0.52
# 142       19       0                0.28
# 148       25       0                0.43
# 150       13       0                0.25
# 155       22       0                0.25
# 162       27       0                0.49
# 166       25       0                0.45
# 170       22       0                0.24
# 181       17       0                0.22
# 182       21       0                0.59
